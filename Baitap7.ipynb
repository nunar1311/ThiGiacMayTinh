# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
my_path = "../ThiGiacMayTinh/images/06.jpg"

img = Image.open(my_path)

plt.imshow(img)

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x, y, color='red')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 15, 20, 40, 15]
plt.plot(x, y, color='red')
plt.title('Ví dụ về biểu đồ')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]

plt.plot(x, y, color='blue')
plt.title('Biểu đồ ví dụ với màu xanh')

plt.axis('off')
plt.show()

# %%
img = Image.open(my_path)
x = [100, 100, 400, 400]
y = [200, 300, 200, 300]

plt.imshow(img)
plt.plot(x,y, 'bo--')
plt.show()
