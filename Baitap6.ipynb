# %%
from PIL import Image
from imageTools import *
from IPython.display import display

# %%
my_path = "../ThiGiacMayTinh/images/06.jpg"

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=680x356>

# %%
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=680x356>

# %%
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=680x356>
# <PIL.Image.Image image mode=L size=680x356>
# <PIL.Image.Image image mode=L size=680x356>

# %%
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=680x356>
